# %%
import pandas as pd

# Load data
df = pd.read_csv('Tweets.csv')

df_clean = df.dropna(subset=['tweet_location']).copy()

# %%
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from tqdm import tqdm

# %%
geolocator = Nominatim(user_agent="tweet_geo_cleaner", timeout=10)
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1) 


def get_coordinates(location):
    try:
        location = location.strip()  
        if not location:
            return (None, None)
       
        geo = geocode(f"{location}, USA")
        if geo:
            return (geo.latitude, geo.longitude)
        return (None, None)
    except:
        return (None, None)


unique_locations = df_clean['tweet_location'].unique()
location_to_coord = {}
for loc in tqdm(unique_locations, desc="Geocoding"):
    location_to_coord[loc] = get_coordinates(loc)


df_clean['tweet_coord'] = df_clean['tweet_location'].map(location_to_coord)


df_clean = df_clean.dropna(subset=['tweet_coord'])
print(f"Final cleaned shape: {df_clean.shape}")
# Out:
# Geocoding: 100%|██████████| 3081/3081 [55:38<00:00,  1.08s/it]
# Final cleaned shape: (9907, 15)

# %%
df_clean.to_csv("df_clean.csv", index=False)

# %%
import pandas as pd
df_clean = df = pd.read_csv('df_clean.csv')
df_clean.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570301083672813571           neutral                        0.6837
# 1  570300616901320704          positive                        0.6745
# 2  570300248553349120           neutral                        0.6340
# 3  570299953286942721          positive                        0.6559
# 4  570295459631263746          positive                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                        0.0  Virgin America
# 2            NaN                        NaN  Virgin America
# 3            NaN                        NaN  Virgin America
# 4            NaN                        NaN  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN  yvonnalynn                 NaN              0
# 1                    NaN  cjmcginnis                 NaN              0
# 2                    NaN       pilot                 NaN              0
# 3                    NaN    dhepburn                 NaN              0
# 4                    NaN  YupitsTate                 NaN              0
#
#                                                 text  \
# 0  @VirginAmerica I didn't today... Must mean I n...
# 1  @VirginAmerica yes, nearly every time I fly VX...
# 2  @VirginAmerica Really missed a prime opportuni...
# 3    @virginamerica Well, I didn't…but NOW I DO! :-D
# 4  @VirginAmerica it was amazing, and arrived an ...
#
#                   tweet_coord              tweet_created    tweet_location  \
# 0                (None, None)  2015-02-24 11:15:48 -0800         Lets Play
# 1  (37.7792588, -122.4193286)  2015-02-24 11:13:57 -0800  San Francisco CA
# 2   (34.0536909, -118.242766)  2015-02-24 11:12:29 -0800       Los Angeles
# 3   (32.7174202, -117.162772)  2015-02-24 11:11:19 -0800         San Diego
# 4   (34.0536909, -118.242766)  2015-02-24 10:53:27 -0800       Los Angeles
#
#                 user_timezone
# 0  Central Time (US & Canada)
# 1  Pacific Time (US & Canada)
# 2  Pacific Time (US & Canada)
# 3  Pacific Time (US & Canada)
# 4  Eastern Time (US & Canada)

# %%
import requests
import pandas as pd
from dateutil import parser

# Load dataset
df = pd.read_csv('df_clean.csv')

# Parse tweet_coord into latitude & longitude
def parse_coordinates(coord):
    try:
        coord = eval(coord)  # Convert string to tuple
        if isinstance(coord, (list, tuple)) and len(coord) == 2:
            return coord[0], coord[1]
    except:
        return None, None

# %%
df["latitude"], df["longitude"] = zip(*df["tweet_coord"].apply(parse_coordinates))

# Convert tweet_created to DateTime format
df["tweet_created"] = df["tweet_created"].apply(lambda x: parser.parse(x[:-6]))  # Remove timezone offset
df["date"] = df["tweet_created"].dt.strftime("%Y-%m-%d")

# %%
df.head()

df.to_csv("df_All_Coordinates.csv", index=False)

# %% [markdown]
# Getting weather data from open-meteo it is a open source free platform to fetch weather data

# %%
from collections import defaultdict
import time


weather_cache = {}

def get_weather_open_meteo(lat, lon, date):
    """Fetches historical weather for a given location & date with caching"""
    
    if pd.isna(lat) or pd.isna(lon):
        return None, None, None, None, None
    
    cache_key = (lat, lon, date)  
    if cache_key in weather_cache:
        return weather_cache[cache_key]  

    url = f"https://archive-api.open-meteo.com/v1/archive?latitude={lat}&longitude={lon}&start_date={date}&end_date={date}&hourly=temperature_2m,humidity_2m,precipitation_sum,windspeed_10m,snowfall"
    
    try:
        response = requests.get(url).json()
        if "hourly" in response:
            temp = response["hourly"]["temperature_2m"][0]
            humidity = response["hourly"]["humidity_2m"][0]
            precipitation = response["hourly"]["precipitation_sum"][0]
            wind_speed = response["hourly"]["windspeed_10m"][0]
            snowfall = response["hourly"]["snowfall"][0]

            weather_cache[cache_key] = (temp, humidity, precipitation, wind_speed, snowfall)  
            return temp, humidity, precipitation, wind_speed, snowfall
    except:
        return None, None, None, None, None

    return None, None, None, None, None

# %%
weather_data = df[["latitude", "longitude", "date"]].drop_duplicates().apply(
    lambda row: get_weather_open_meteo(row["latitude"], row["longitude"], row["date"]), axis=1
)

# %%
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570301083672813571           neutral                        0.6837
# 1  570300616901320704          positive                        0.6745
# 2  570300248553349120           neutral                        0.6340
# 3  570299953286942721          positive                        0.6559
# 4  570295459631263746          positive                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                        0.0  Virgin America
# 2            NaN                        NaN  Virgin America
# 3            NaN                        NaN  Virgin America
# 4            NaN                        NaN  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN  yvonnalynn                 NaN              0
# 1                    NaN  cjmcginnis                 NaN              0
# 2                    NaN       pilot                 NaN              0
# 3                    NaN    dhepburn                 NaN              0
# 4                    NaN  YupitsTate                 NaN              0
#
#                                                 text  \
# 0  @VirginAmerica I didn't today... Must mean I n...
# 1  @VirginAmerica yes, nearly every time I fly VX...
# 2  @VirginAmerica Really missed a prime opportuni...
# 3    @virginamerica Well, I didn't…but NOW I DO! :-D
# 4  @VirginAmerica it was amazing, and arrived an ...
#
#                   tweet_coord       tweet_created    tweet_location  \
# 0                (None, None) 2015-02-24 11:15:48         Lets Play
# 1  (37.7792588, -122.4193286) 2015-02-24 11:13:57  San Francisco CA
# 2   (34.0536909, -118.242766) 2015-02-24 11:12:29       Los Angeles
# 3   (32.7174202, -117.162772) 2015-02-24 11:11:19         San Diego
# 4   (34.0536909, -118.242766) 2015-02-24 10:53:27       Los Angeles
#
#                 user_timezone   latitude   longitude        date
# 0  Central Time (US & Canada)        NaN         NaN  2015-02-24
# 1  Pacific Time (US & Canada)  37.779259 -122.419329  2015-02-24
# 2  Pacific Time (US & Canada)  34.053691 -118.242766  2015-02-24
# 3  Pacific Time (US & Canada)  32.717420 -117.162772  2015-02-24
# 4  Eastern Time (US & Canada)  34.053691 -118.242766  2015-02-24

# %%
df = df[df['tweet_coord'] != "(None, None)"]

df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 1  570300616901320704          positive                        0.6745
# 2  570300248553349120           neutral                        0.6340
# 3  570299953286942721          positive                        0.6559
# 4  570295459631263746          positive                        1.0000
# 6  570289724453216256          positive                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 1            NaN                        0.0  Virgin America
# 2            NaN                        NaN  Virgin America
# 3            NaN                        NaN  Virgin America
# 4            NaN                        NaN  Virgin America
# 6            NaN                        NaN  Virgin America
#
#   airline_sentiment_gold          name negativereason_gold  retweet_count  \
# 1                    NaN    cjmcginnis                 NaN              0
# 2                    NaN         pilot                 NaN              0
# 3                    NaN      dhepburn                 NaN              0
# 4                    NaN    YupitsTate                 NaN              0
# 6                    NaN  HyperCamiLax                 NaN              0
#
#                                                 text  \
# 1  @VirginAmerica yes, nearly every time I fly VX...
# 2  @VirginAmerica Really missed a prime opportuni...
# 3    @virginamerica Well, I didn't…but NOW I DO! :-D
# 4  @VirginAmerica it was amazing, and arrived an ...
# 6  @VirginAmerica I &lt;3 pretty graphics. so muc...
#
#                   tweet_coord       tweet_created    tweet_location  \
# 1  (37.7792588, -122.4193286) 2015-02-24 11:13:57  San Francisco CA
# 2   (34.0536909, -118.242766) 2015-02-24 11:12:29       Los Angeles
# 3   (32.7174202, -117.162772) 2015-02-24 11:11:19         San Diego
# 4   (34.0536909, -118.242766) 2015-02-24 10:53:27       Los Angeles
# 6   (40.7127281, -74.0060152) 2015-02-24 10:30:40               NYC
#
#                 user_timezone   latitude   longitude        date
# 1  Pacific Time (US & Canada)  37.779259 -122.419329  2015-02-24
# 2  Pacific Time (US & Canada)  34.053691 -118.242766  2015-02-24
# 3  Pacific Time (US & Canada)  32.717420 -117.162772  2015-02-24
# 4  Eastern Time (US & Canada)  34.053691 -118.242766  2015-02-24
# 6            America/New_York  40.712728  -74.006015  2015-02-24

# %%
df.head()

df.to_csv("df_All_Coordinates.csv", index=False)
